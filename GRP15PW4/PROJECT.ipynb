# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### IMPORTING DATA ABOUT TEMPERATURE FOR PAST 100 YRS [1916-2016]

# %%
DATA = pd.read_csv("globaltemp.csv")
print(DATA.head())
# Out:
#     Source  Year    Mean
# 0     GCAG  2016  0.9363
# 1  GISTEMP  2016  0.9900
# 2     GCAG  2015  0.8998
# 3  GISTEMP  2015  0.8700
# 4     GCAG  2014  0.7408

# %%
##WE WILL FILTER DATA FOR SOURCE AND TIME PERIOD 
DATA = DATA[DATA['Source'] == 'GISTEMP'].reset_index()[["Source", "Year", "Mean"]]
print(DATA.head())
# Out:
#     Source  Year  Mean
# 0  GISTEMP  2016  0.99
# 1  GISTEMP  2015  0.87
# 2  GISTEMP  2014  0.74
# 3  GISTEMP  2013  0.65
# 4  GISTEMP  2012  0.63

# %%
DATA = DATA[DATA['Year'] >= 1916].reset_index()[["Source", "Year", "Mean"]]
print(DATA.head())
# Out:
#     Source  Year  Mean
# 0  GISTEMP  2016  0.99
# 1  GISTEMP  2015  0.87
# 2  GISTEMP  2014  0.74
# 3  GISTEMP  2013  0.65
# 4  GISTEMP  2012  0.63

# %% [markdown]
# ## GRAPH BETWEEN TEMP VS YEAR [100 YRS]

# %%
##INSTEAD OF SEABORN WE CAN USE NORMAL WALA GRAPH PLOTTING BACKGROUND WILL BE WHITE 
sns.set()
# x axis values
x = DATA['Year']
# corresponding y axis values
y = DATA['Mean']
 
# plotting the points
plt.plot(x, y)
 
# naming the x axis
plt.xlabel('Years-->')
# naming the y axis
plt.ylabel('Mean -->')
 
# giving a title to my graph
plt.title('Average Global Mean[rise] Temperature')
 
# function to show the plot
plt.show()

# %%
df_rice = pd.read_csv("rice-yields.csv")
df_rice = df_rice[df_rice['Entity']=='Nigeria'].reset_index()[["Entity", "Code", "Year","Crops - Cereals (Rice Milled Eqv) - 1817 - Yield - 5419 - hg/ha"]]
df_rice = df_rice[df_rice['Year']<=2016].reset_index()[["Entity", "Code", "Year","Crops - Cereals (Rice Milled Eqv) - 1817 - Yield - 5419 - hg/ha"]]
df_rice=df_rice.rename(columns={'Crops - Cereals (Rice Milled Eqv) - 1817 - Yield - 5419 - hg/ha':'rice-yields'},inplace=False)
print(df_rice.head())
# Out:
#     Entity Code  Year  rice-yields
# 0  Nigeria  NGA  1961       0.7388
# 1  Nigeria  NGA  1962       0.7747
# 2  Nigeria  NGA  1963       0.7577
# 3  Nigeria  NGA  1964       0.7113
# 4  Nigeria  NGA  1965       0.6808

# %%
sns.lineplot(df_rice['Year'], df_rice['rice-yields'])
plt.ylabel("Rice Production in Nigeria")
plt.title("Annual Rice production in Nigeria")
# Out:
# Text(0.5, 1.0, 'Annual Rice production in Nigeria')

# %%
sns.set()
ax1=sns.lineplot(DATA['Year'], DATA['Mean'])
plt.ylabel("Mean")
plt.title("Average Global Mean rise Temperature and wheat production in Nigeria")

ax2=sns.lineplot(df_rice['Year'], df_rice['rice-yields'])
plt.ylabel("Mean temperature/prod per hectare rice in Nigeria ")
# Out:
# Text(0, 0.5, 'Mean temperature/prod per hectare rice in Nigeria ')

# %% [markdown]
# ### Observe Carefully -->Interestingly enough, there seems to be a significant drop in rice production in Nigeria between 1985 and 2005.

# %%
df_wheat = pd.read_csv("wheat-yieldsm.csv")
df_wheat = df_wheat[df_wheat['Entity']=='Nigeria'].reset_index()[["Entity", "Code", "Year", 'Crops - Wheat - 15 - Yield - 5419 - hg/ha']]
df_wheat=df_wheat.rename(columns={'Crops - Wheat - 15 - Yield - 5419 - hg/ha':'wheat-yields'},inplace=False)
print(df_wheat.head())
sns.set()
sns.lineplot(DATA['Year'], DATA['Mean'])
plt.ylabel("Mean")
plt.title("Average Global Mean Temperature and wheat production in Nigeria")
sns.lineplot(df_wheat['Year'], df_wheat['wheat-yields'])
plt.ylabel("Mean temperature/production per hectare wheat in Nigeria ")
# Out:
#     Entity Code  Year  wheat-yields
# 0  Nigeria  NGA  1961        1.7778
# 1  Nigeria  NGA  1962        1.7778
# 2  Nigeria  NGA  1963        1.7778
# 3  Nigeria  NGA  1964        1.8182
# 4  Nigeria  NGA  1965        1.8182
# Text(0, 0.5, 'Mean temperature/production per hectare wheat in Nigeria ')

# %% [markdown]
# ### There also seems to be a slight drop in rice production in Haiti-->

# %%
df_rrr = pd.read_csv("rice-yields.csv")
df_rrr = df_rrr[df_rrr['Entity']=='Haiti'].reset_index()[["Entity", "Code", "Year", 'Crops - Cereals (Rice Milled Eqv) - 1817 - Yield - 5419 - hg/ha']]
df_rrr=df_rrr.rename(columns={'Crops - Cereals (Rice Milled Eqv) - 1817 - Yield - 5419 - hg/ha':'rice-yields'},inplace=False)
print(df_rrr.head())
sns.set()
sns.lineplot(DATA['Year'], DATA['Mean'])
plt.ylabel("Mean")
plt.title("Average Global Mean Temperature and rice production in Haiti")
sns.lineplot(df_rrr['Year'], df_rrr['rice-yields'])
plt.ylabel("Mean temperature/production per hectare rice in Haiti")
# Out:
#   Entity Code  Year  rice-yields
# 0  Haiti  HTI  1961       0.9905
# 1  Haiti  HTI  1962       0.9989
# 2  Haiti  HTI  1963       1.0081
# 3  Haiti  HTI  1964       1.0073
# 4  Haiti  HTI  1965       1.0196
# Text(0, 0.5, 'Mean temperature/production per hectare rice in Haiti')

# %% [markdown]
# ## RANDOM CASESTUDY-->INDIA AND THAILAND[WHEAT ONLY]

# %%
df_wheatt = pd.read_csv("wheat-yieldsm.csv")
df_wheatt = df_wheatt[df_wheatt['Entity']=='Thailand'].reset_index()[["Entity", "Code", "Year", 'Crops - Wheat - 15 - Yield - 5419 - hg/ha']]
df_wheatt=df_wheatt.rename(columns={'Crops - Wheat - 15 - Yield - 5419 - hg/ha':'wheat-yields'},inplace=False)
print(df_wheatt.head())
sns.set()
sns.lineplot(DATA['Year'], DATA['Mean'])
plt.ylabel("Mean")
plt.title("Average Global Mean Temperature and wheat production in Thailand")
sns.lineplot(df_wheatt['Year'], df_wheatt['wheat-yields'])
plt.ylabel("Mean temperature/production wheat in Thailand ")
# Out:
#      Entity Code  Year  wheat-yields
# 0  Thailand  THA  1986        1.1932
# 1  Thailand  THA  1987        1.2500
# 2  Thailand  THA  1988        0.5546
# 3  Thailand  THA  1989        0.7254
# 4  Thailand  THA  1990        0.6107
# Text(0, 0.5, 'Mean temperature/production wheat in Thailand ')

# %%
df_wheatin = pd.read_csv("wheat-yieldsm.csv")
df_wheatin = df_wheatin[df_wheatin['Entity']=='India'].reset_index()[["Entity", "Code", "Year", 'Crops - Wheat - 15 - Yield - 5419 - hg/ha']]
df_wheatin=df_wheatin.rename(columns={'Crops - Wheat - 15 - Yield - 5419 - hg/ha':'wheat-yields'},inplace=False)
print(df_wheatin.head())
sns.set()
sns.lineplot(DATA['Year'], DATA['Mean'])
plt.ylabel("Mean")
plt.title("Average Global Mean Temperature and wheat production in India")
sns.lineplot(df_wheatin['Year'], df_wheatin['wheat-yields'])
plt.ylabel("Mean temperature/production wheat in India ")
# Out:
#   Entity Code  Year  wheat-yields
# 0  India  IND  1961        0.8507
# 1  India  IND  1962        0.8896
# 2  India  IND  1963        0.7929
# 3  India  IND  1964        0.7299
# 4  India  IND  1965        0.9132
# Text(0, 0.5, 'Mean temperature/production wheat in India ')

# %% [markdown]
# #### SMALL OBSERVATION :BOTH INDIA AND THAILAND SEEM TO NOT BE AFFECTED MUCH BY THE CLIMATE CHANGE [EVEN-THOUGH SOME DROP PATTERNS ARE STILL OBSERVERD ]DUE TO VARIOUS FACTORS LIKE TECHNOLOGY ADVANCEMENT ETC  WE CAN CONCLUDE ATLEAST FOR FOOD SUPPLY CHAIN INDIA AND THAILAND ARE NOT AS VULUNERABLE AS NIGERIA AND HAITI LIKE COUNTRIES

# %% [markdown]
# ### FINDING CORELATION

# %%
df_rrr
df_rrr = df_rrr[df_rrr['Year']>=1972]
df_rrr = df_rrr[df_rrr['Year']<=2008]

# %%
df_rrr
sns.lineplot(df_rrr['Year'], df_rrr['rice-yields'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='rice-yields'>

# %%
#NOW LETS APPLY LINEAR MODEL 
from sklearn.model_selection import train_test_split
X=df_rrr['Year']
y=df_rrr['rice-yields']

# %%
X
# Out:
# 11    1972
# 12    1973
# 13    1974
# 14    1975
# 15    1976
# 16    1977
# 17    1978
# 18    1979
# 19    1980
# 20    1981
# 21    1982
# 22    1983
# 23    1984
# 24    1985
# 25    1986
# 26    1987
# 27    1988
# 28    1989
# 29    1990
# 30    1991
# 31    1992
# 32    1993
# 33    1994
# 34    1995
# 35    1996
# 36    1997
# 37    1998
# 38    1999
# 39    2000
# 40    2001
# 41    2002
# 42    2003
# 43    2004
# 44    2005
# 45    2006
# 46    2007
# 47    2008
# Name: Year, dtype: int64

# %%
y
# Out:
# 11    1.0863
# 12    0.9744
# 13    1.0734
# 14    1.0230
# 15    1.1177
# 16    0.8439
# 17    0.7228
# 18    0.8731
# 19    0.9196
# 20    0.9481
# 21    0.9392
# 22    0.9437
# 23    0.9414
# 24    0.9120
# 25    0.8975
# 26    0.8852
# 27    0.8758
# 28    0.8838
# 29    0.9037
# 30    0.8890
# 31    0.8858
# 32    0.8668
# 33    0.8479
# 34    0.8511
# 35    0.8796
# 36    0.8949
# 37    0.8370
# 38    0.8844
# 39    0.8381
# 40    0.7484
# 41    0.8332
# 42    0.8336
# 43    0.8518
# 44    0.8743
# 45    0.8779
# 46    0.8799
# 47    0.8773
# Name: rice-yields, dtype: float64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=11)
#we will also use random_state

# %%
X_train
# Out:
# 17    1978
# 14    1975
# 30    1991
# 44    2005
# 19    1980
# 22    1983
# 39    2000
# 32    1993
# 40    2001
# 47    2008
# 16    1977
# 21    1982
# 41    2002
# 33    1994
# 13    1974
# 15    1976
# 42    2003
# 37    1998
# 11    1972
# 46    2007
# 43    2004
# 35    1996
# 29    1990
# 18    1979
# 12    1973
# 23    1984
# 24    1985
# 28    1989
# 38    1999
# 27    1988
# 36    1997
# Name: Year, dtype: int64

# %%
y_train
y_train.values.reshape(-1,1)
# Out:
# array([[0.7228],
#        [1.023 ],
#        [0.889 ],
#        [0.8743],
#        [0.9196],
#        [0.9437],
#        [0.8381],
#        [0.8668],
#        [0.7484],
#        [0.8773],
#        [0.8439],
#        [0.9392],
#        [0.8332],
#        [0.8479],
#        [1.0734],
#        [1.1177],
#        [0.8336],
#        [0.837 ],
#        [1.0863],
#        [0.8799],
#        [0.8518],
#        [0.8796],
#        [0.9037],
#        [0.8731],
#        [0.9744],
#        [0.9414],
#        [0.912 ],
#        [0.8838],
#        [0.8844],
#        [0.8758],
#        [0.8949]])

# %%
from sklearn.linear_model import LinearRegression
clf=LinearRegression()

# %%
import numpy as np
import matplotlib.pyplot as plt
 
def estimate_coef(x, y):
    # number of observations/points
    n = np.size(x)
 
    # mean of x and y vector
    m_x = np.mean(x)
    m_y = np.mean(y)
 
    # calculating cross-deviation and deviation about x
    SS_xy = np.sum(y*x) - n*m_y*m_x
    SS_xx = np.sum(x*x) - n*m_x*m_x
 
    # calculating regression coefficients
    b_1 = SS_xy / SS_xx
    b_0 = m_y - b_1*m_x
 
    return (b_0, b_1)
 
def plot_regression_line(x, y, b):
    # plotting the actual points as scatter plot
    plt.scatter(x, y, color = "m",
               marker = "o", s = 30)
 
    # predicted response vector
    y_pred = b[0] + b[1]*x
 
    # plotting the regression line
    plt.plot(x, y_pred, color = "g")
 
    # putting labels
    plt.xlabel('x')
    plt.ylabel('y')
 
    # function to show plot
    plt.show()
 
def main():
    # observations / data
    
 
    # estimating coefficients
    b = estimate_coef(X_train,y_train)
    print("Estimated coefficients:\nb_0 = {}  \
          \nb_1 = {}".format(b[0], b[1]))
 
    # plotting regression line
    plot_regression_line(X_train,y_train, b)
 
if __name__ == "__main__":
    main()
# Out:
# Estimated coefficients:
# b_0 = 9.784870373055018
# b_1 = -0.004465752015380341

# %%
print(b_0,b_1)
predict=b_0 +b_1*X_test
# Out:
# 9.442060575213588 -0.004289124901359839

# %%
X_test
# Out:
# 26    1987
# 20    1981
# 45    2006
# 34    1995
# 31    1992
# 25    1986
# Name: Year, dtype: int64

# %%
predict
# Out:
# 26    0.919569
# 20    0.945304
# 45    0.838076
# 34    0.885256
# 31    0.898124
# 25    0.923859
# Name: Year, dtype: float64

# %%
df_rrr
# Out:
#    Entity Code  Year  rice-yields
# 11  Haiti  HTI  1972       1.0863
# 12  Haiti  HTI  1973       0.9744
# 13  Haiti  HTI  1974       1.0734
# 14  Haiti  HTI  1975       1.0230
# 15  Haiti  HTI  1976       1.1177
# 16  Haiti  HTI  1977       0.8439
# 17  Haiti  HTI  1978       0.7228
# 18  Haiti  HTI  1979       0.8731
# 19  Haiti  HTI  1980       0.9196
# 20  Haiti  HTI  1981       0.9481
# 21  Haiti  HTI  1982       0.9392
# 22  Haiti  HTI  1983       0.9437
# 23  Haiti  HTI  1984       0.9414
# 24  Haiti  HTI  1985       0.9120
# 25  Haiti  HTI  1986       0.8975
# 26  Haiti  HTI  1987       0.8852
# 27  Haiti  HTI  1988       0.8758
# 28  Haiti  HTI  1989       0.8838
# 29  Haiti  HTI  1990       0.9037
# 30  Haiti  HTI  1991       0.8890
# 31  Haiti  HTI  1992       0.8858
# 32  Haiti  HTI  1993       0.8668
# 33  Haiti  HTI  1994       0.8479
# 34  Haiti  HTI  1995       0.8511
# 35  Haiti  HTI  1996       0.8796
# 36  Haiti  HTI  1997       0.8949
# ...

# %%
y_test
# Out:
# 26    0.8852
# 20    0.9481
# 45    0.8779
# 34    0.8511
# 31    0.8858
# 25    0.8975
# Name: rice-yields, dtype: float64

# %%
print(predict,y_test)
# Out:
# 26    0.919569
# 20    0.945304
# 45    0.838076
# 34    0.885256
# 31    0.898124
# 25    0.923859
# Name: Year, dtype: float64 26    0.8852
# 20    0.9481
# 45    0.8779
# 34    0.8511
# 31    0.8858
# 25    0.8975
# Name: rice-yields, dtype: float64

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(y_test,predict)
print(mse*100) 
print("%")
# Out:
# 0.07980546292158033
# %

# %%
#accuracy from first look is 80+% which is suffient in real time prediction 
df_wheat
df_wheat = df_wheat[df_wheat['Year']>=1961]
df_wheat = df_wheat[df_wheat['Year']<=1991]

# %%
df_wheat
# Out:
#      Entity Code  Year  wheat-yields
# 0   Nigeria  NGA  1961        1.7778
# 1   Nigeria  NGA  1962        1.7778
# 2   Nigeria  NGA  1963        1.7778
# 3   Nigeria  NGA  1964        1.8182
# 4   Nigeria  NGA  1965        1.8182
# 5   Nigeria  NGA  1966        1.8182
# 6   Nigeria  NGA  1967        1.9091
# 7   Nigeria  NGA  1968        1.8182
# 8   Nigeria  NGA  1969        1.8182
# 9   Nigeria  NGA  1970        1.7273
# 10  Nigeria  NGA  1971        1.7391
# 11  Nigeria  NGA  1972        1.7391
# 12  Nigeria  NGA  1973        1.4286
# 13  Nigeria  NGA  1974        1.5000
# 14  Nigeria  NGA  1975        1.6364
# 15  Nigeria  NGA  1976        1.8000
# 16  Nigeria  NGA  1977        2.0000
# 17  Nigeria  NGA  1978        2.0000
# 18  Nigeria  NGA  1979        2.2000
# 19  Nigeria  NGA  1980        2.4000
# 20  Nigeria  NGA  1981        2.6000
# 21  Nigeria  NGA  1982        2.6000
# 22  Nigeria  NGA  1983        1.8571
# 23  Nigeria  NGA  1984        1.6875
# ...

# %%
sns.lineplot(df_wheat['Year'], df_wheat['wheat-yields'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='wheat-yields'>

# %%
#NOW LETS APPLY LINEAR MODEL 
from sklearn.model_selection import train_test_split
X2=df_wheat['Year']
y2=df_wheat['wheat-yields']

# %%
X2_train,X2_test,y2_train,y2_test=train_test_split(X2,y2,test_size=0.15)

# %%
import numpy as np
import matplotlib.pyplot as plt
 
def estimate_coef(x, y):
    # number of observations/points
    n = np.size(x)
 
    # mean of x and y vector
    m_x = np.mean(x)
    m_y = np.mean(y)
 
    # calculating cross-deviation and deviation about x
    SS_xy = np.sum(y*x) - n*m_y*m_x
    SS_xx = np.sum(x*x) - n*m_x*m_x
 
    # calculating regression coefficients
    b_12 = SS_xy / SS_xx
    b_02 = m_y - b_1*m_x
 
    return (b_02, b_12)
 
def plot_regression_line(x, y, b):
    # plotting the actual points as scatter plot
    plt.scatter(x, y, color = "m",
               marker = "o", s = 30)
 
    # predicted response vector
    y_pred = b[0] + b[1]*x
 
    # plotting the regression line
    plt.plot(x, y_pred, color = "g")
 
    # putting labels
    plt.xlabel('x')
    plt.ylabel('y')
 
    # function to show plot
    plt.show()
 
def main():
    # observations / data
    
 
    # estimating coefficients
    b = estimate_coef(X2_train,y2_train)
    print("Estimated coefficients:\nb_0 = {}  \
          \nb_1 = {}".format(b[0], b[1]))
 
    # plotting regression line
    plot_regression_line(X2_train,y2_train, b)
 
if __name__ == "__main__":
    main()
# Out:
# Estimated coefficients:
# b_0 = 10.225504285901799
# b_1 = -0.012384319867480462

# %%
print(b_02,b_12)
predict2=b_02 +b_12*X2_test
# Out:
# 17.769942101873127 -0.008091136821137145

# %%
X2_test
# Out:
# 26    1987
# 7     1968
# 21    1982
# 24    1985
# 9     1970
# Name: Year, dtype: int64

# %%
predict2
# Out:
# 26    1.692853
# 7     1.846585
# 21    1.733309
# 24    1.709036
# 9     1.830403
# Name: Year, dtype: float64

# %%
df_wheat
# Out:
#      Entity Code  Year  wheat-yields
# 0   Nigeria  NGA  1961        1.7778
# 1   Nigeria  NGA  1962        1.7778
# 2   Nigeria  NGA  1963        1.7778
# 3   Nigeria  NGA  1964        1.8182
# 4   Nigeria  NGA  1965        1.8182
# 5   Nigeria  NGA  1966        1.8182
# 6   Nigeria  NGA  1967        1.9091
# 7   Nigeria  NGA  1968        1.8182
# 8   Nigeria  NGA  1969        1.8182
# 9   Nigeria  NGA  1970        1.7273
# 10  Nigeria  NGA  1971        1.7391
# 11  Nigeria  NGA  1972        1.7391
# 12  Nigeria  NGA  1973        1.4286
# 13  Nigeria  NGA  1974        1.5000
# 14  Nigeria  NGA  1975        1.6364
# 15  Nigeria  NGA  1976        1.8000
# 16  Nigeria  NGA  1977        2.0000
# 17  Nigeria  NGA  1978        2.0000
# 18  Nigeria  NGA  1979        2.2000
# 19  Nigeria  NGA  1980        2.4000
# 20  Nigeria  NGA  1981        2.6000
# 21  Nigeria  NGA  1982        2.6000
# 22  Nigeria  NGA  1983        1.8571
# 23  Nigeria  NGA  1984        1.6875
# ...

# %%
X2_train
# Out:
# 3     1964
# 6     1967
# 10    1971
# 16    1977
# 14    1975
# 17    1978
# 18    1979
# 25    1986
# 28    1989
# 19    1980
# 30    1991
# 13    1974
# 0     1961
# 23    1984
# 27    1988
# 2     1963
# 8     1969
# 4     1965
# 22    1983
# 15    1976
# 5     1966
# 11    1972
# 12    1973
# 1     1962
# 20    1981
# 29    1990
# Name: Year, dtype: int64

# %%
A=int(input("enter a year for some magic >=2002"))
predictxm=b_0 +b_1*A
# Out:
# enter a year for some magic >=20022200

# %%
predictxm
# Out:
# 0.005985792221942177
